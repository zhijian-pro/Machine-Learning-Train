# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import  fetch_lfw_people

# %%
faces = fetch_lfw_people()
# Out:
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976012
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976009
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976006
# Downloading LFW data (~200MB): https://ndownloader.figshare.com/files/5976015

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.images
# Out:
# array([[[  34.        ,   29.33333397,   22.33333397, ...,   20.        ,
#            25.66666603,   30.66666603],
#         [  37.33333206,   32.        ,   25.33333397, ...,   21.        ,
#            26.66666603,   32.        ],
#         [  33.33333206,   32.33333206,   40.33333206, ...,   23.66666603,
#            28.        ,   35.66666794],
#         ...,
#         [ 166.        ,   97.        ,   44.33333206, ...,    9.66666698,
#            14.33333302,   12.33333302],
#         [  64.        ,   38.66666794,   30.        , ...,   12.66666698,
#            16.        ,   14.        ],
#         [  30.66666603,   29.        ,   26.33333397, ...,   14.66666698,
#            16.        ,   14.        ]],
#
#        [[ 158.        ,  160.66667175,  169.66667175, ...,   74.33333588,
#            28.        ,   15.66666698],
#         [ 156.        ,  155.33332825,  163.33332825, ...,   83.        ,
#            25.66666603,   14.        ],
#         [ 146.66667175,  143.66667175,  144.66667175, ...,   82.33333588,
#            26.        ,   14.66666698],
#         ...,
#         [ 118.66666412,  120.        ,  170.        , ...,  131.33332825,
#           127.33333588,  126.        ],
#         [ 125.        ,  117.66666412,  141.33332825, ...,  133.33332825,
#           132.        ,  129.33332825],
#         [ 128.66667175,  122.66666412,  121.66666412, ...,  138.66667175,
#           135.33332825,  130.33332825]],
#
#        [[  77.        ,   81.33333588,   88.        , ...,   71.        ,
#            80.66666412,   65.33333588],
#         [  77.66666412,   89.        ,  104.66666412, ...,   75.66666412,
#            72.        ,   69.        ],
#         [  83.        ,   97.        ,  117.        , ...,   80.33333588,
#            80.33333588,   66.        ],
#         ...,
#         [  13.33333302,   16.        ,   32.        , ...,  183.66667175,
#           131.        ,   58.33333206],
#         [  46.33333206,   70.        ,   94.33333588, ...,  188.66667175,
#           143.66667175,   65.        ],
#         [ 112.33333588,  122.        ,  118.        , ...,  192.        ,
#           145.33332825,   66.33333588]],
#
#        ...,
#        [[  38.        ,   41.66666794,   55.33333206, ...,   28.66666603,
#            26.33333397,   29.33333397],
#         [  46.66666794,   49.33333206,   60.66666794, ...,   30.33333397,
#            26.33333397,   31.        ],
#         [  50.33333206,   53.66666794,   63.        , ...,   32.33333206,
#            27.66666603,   34.33333206],
#         ...,
#         [  71.        ,  123.        ,  204.66667175, ...,   58.33333206,
#            47.        ,   38.        ],
#         [  70.66666412,   85.66666412,  148.66667175, ...,   64.        ,
#            57.66666794,   46.66666794],
#         [  70.33333588,   71.66666412,   97.33333588, ...,   66.        ,
#            63.66666794,   54.33333206]],
#
#        [[  16.66666603,   24.33333397,   60.33333206, ...,  177.33332825,
#           175.        ,  174.33332825],
#         [  16.33333397,   22.33333397,   55.66666794, ...,  177.33332825,
#           174.66667175,  174.        ],
#         [  18.33333397,   25.66666603,   61.        , ...,  175.33332825,
#           172.66667175,  172.33332825],
#         ...,
#         [  21.66666603,   21.33333397,   22.66666603, ...,  221.33332825,
#           132.66667175,   52.        ],
#         [  22.        ,   21.66666603,   22.33333397, ...,  219.        ,
#           137.        ,   59.        ],
#         [  22.33333397,   22.        ,   22.66666603, ...,  219.        ,
#           143.33332825,   69.33333588]],
#
#        [[  58.33333206,   48.        ,   20.        , ...,   66.        ,
#           101.66666412,   94.66666412],
#         [  62.        ,   32.66666794,   26.33333397, ...,   50.        ,
#            89.66666412,  101.33333588],
#         [  56.33333206,   29.33333397,   47.        , ...,   55.33333206,
#            76.66666412,  106.33333588],
#         ...,
#         [ 116.33333588,  106.33333588,   95.        , ...,  113.33333588,
#           100.33333588,   88.        ],
#         [ 116.66666412,  104.66666412,   93.33333588, ...,  115.66666412,
#           103.66666412,  112.        ],
#         [ 116.33333588,  104.        ,   95.33333588, ...,  116.        ,
#           106.33333588,  143.33332825]]], dtype=float32)

# %%
faces.data.shape
# Out:
# (13233, 2914)

# %%
random_indexes = np.random.permutation(len(faces.data))
X  = faces.data[random_indexes]
example_faces = X[:36,:]
example_faces.shape
# Out:
# (36, 2914)

# %%
def plot_faces(faces):
    
    fig, axes = plt.subplots(6, 6, figsize=(10, 10),
                         subplot_kw={'xticks':[], 'yticks':[]},
    gridspec_kw=dict(hspace=0.1, wspace=0.1)) 
    for i, ax in enumerate(axes.flat):
        ax.imshow(faces[i].reshape(62, 47), cmap='bone')
    plt.show()
    
plot_faces(example_faces)

# %% [markdown]
# ## 特征脸

# %%
# %%time 
from sklearn.decomposition import PCA
pca = PCA(svd_solver = "randomized")
pca.fit(X)
# Out:
# CPU times: user 2min 20s, sys: 5.48 s, total: 2min 26s
# Wall time: 1min 33s

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plot_faces(pca.components_[:36,:])

# %% [markdown]
# ### 更多关于lfw_people数据集

# %%
faces2 = fetch_lfw_people(min_faces_per_person=60)
faces2.data.shape
# Out:
# (1348, 2914)

# %%
faces2.target_names
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Hugo Chavez', 'Junichiro Koizumi',
#        'Tony Blair'],
#       dtype='<U17')

# %%
len(faces2.target_names)
# Out:
# 8
